# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#   Country Name  Access to electricity (% of population) - EG.ELC.ACCS.ZS  \
# 0       Angola                                                NaN
# 1       Angola                                          20.000000
# 2       Angola                                          26.383869
# 3       Angola                                          27.465635
# 4       Angola                                          28.536760
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG  \
# 0                                                NaN
# 1                                          18.457388
# 2                                          37.239379
# 3                                           6.421468
# 4                                          -8.470402
#
#    Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS  \
# 0                                          89.685831
# 1                                          75.388944
# ...

# %%
df.isnull().sum()
# Out:
# Country Name                                                                               0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                   1
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG          45
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                  1
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                  5
# GDP (current US$) - NY.GDP.MKTP.CD                                                         0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                     5
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                 35
# Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                  1
# Trade (% of GDP) - NE.TRD.GNFS.ZS                                                          1
# ...

# %%
sns.heatmap(df.isnull(), yticklabels= False, cbar=False, cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
df.fillna(0)
# Out:
#                Country Name  \
# 0                    Angola
# 1                    Angola
# 2                    Angola
# 3                    Angola
# 4                    Angola
# ..                      ...
# 318  Bosnia and Herzegovina
# 319  Bosnia and Herzegovina
# 320  Bosnia and Herzegovina
# 321  Bosnia and Herzegovina
# 322  Bosnia and Herzegovina
#
#      Access to electricity (% of population) - EG.ELC.ACCS.ZS  \
# 0                                             0.000000
# 1                                            20.000000
# 2                                            26.383869
# 3                                            27.465635
# 4                                            28.536760
# ..                                                 ...
# 318                                         100.000000
# 319                                          99.700000
# 320                                         100.000000
# ...

# %%
col_1 = df["Access to electricity (% of population) - EG.ELC.ACCS.ZS"]
col_2 = df["Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG"]
col_3 = df["Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS"]
col_4 = df["Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS"]
col_6 = df["Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS"]
col_7 = df["Gross savings (% of GDP) - NY.GNS.ICTR.ZS"]
col_8 = df["Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS"]
col_9 = df["Trade (% of GDP) - NE.TRD.GNFS.ZS"]
col_13 = df["Gini index (World Bank estimate) - SI.POV.GINI"]

# %%
df["Country Name"].unique()
# Out:
# array(['Angola', 'Albania', 'United Arab Emirates', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Burundi',
#        'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bulgaria',
#        'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina'], dtype=object)

# %%
# For Angola
print(df.iloc[0:19, 1].mean()) #col1
print(df.iloc[0:19, 2].mean()) #col2
print(df.iloc[0:19, 3].mean()) #col3
print(df.iloc[0:19, 4].mean()) #col4
print(df.iloc[0:19, 6].mean()) #col6
print(df.iloc[0:19, 7].mean()) #col7
print(df.iloc[0:19, 8].mean()) #col8
print(df.iloc[0:19, 9].mean()) #col9
print(df.iloc[0:19, 13].mean()) #col13

df.iloc[0:19, 1].replace(np.nan, df.iloc[0:19, 1].mean(), inplace=True)
df.iloc[0:19, 2].replace(np.nan, df.iloc[0:19, 2].mean(), inplace=True)
df.iloc[0:19, 3].replace(np.nan, df.iloc[0:19, 3].mean(), inplace=True)
df.iloc[0:19, 4].replace(np.nan, df.iloc[0:19, 4].mean(), inplace=True)
df.iloc[0:19, 6].replace(np.nan, df.iloc[0:19,6].mean(), inplace=True)
df.iloc[0:19, 7].replace(np.nan, df.iloc[0:19, 7].mean(), inplace=True)
df.iloc[0:19, 8].replace(np.nan, df.iloc[0:19, 8].mean(), inplace=True)
df.iloc[0:19, 9].replace(np.nan, df.iloc[0:19, 9].mean(), inplace=True)
df.iloc[0:19, 13].replace(np.nan, df.iloc[0:19, 13].mean(), inplace=True)

df.iloc[0:19, :].isnull().sum()
# Out:
# 34.51899776888889
# 4.933746641333332
# 56.01623589789474
# 57.66807758052632
# 86.34719981947369
# 31.931342958421055
# 42.178371500000004
# 98.19460740105264
# 48.666666666666664
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
# For Albania
print(df.iloc[19:38, 1].mean()) #col1
print(df.iloc[19:38, 2].mean()) #col2
print(df.iloc[19:38, 3].mean()) #col3
print(df.iloc[19:38, 4].mean()) #col4
print(df.iloc[19:38, 6].mean()) #col6
print(df.iloc[19:38, 7].mean()) #col7
print(df.iloc[19:38, 8].mean()) #col8
print(df.iloc[19:38, 9].mean()) #col9
print(df.iloc[19:38, 13].mean()) #col13

df.iloc[19:38, 1].replace(np.nan, df.iloc[19:38, 1].mean(), inplace=True)
df.iloc[19:38, 2].replace(np.nan, df.iloc[19:38, 2].mean(), inplace=True)
df.iloc[19:38, 3].replace(np.nan, df.iloc[19:38, 3].mean(), inplace=True)
df.iloc[19:38, 4].replace(np.nan, df.iloc[19:38, 4].mean(), inplace=True)
df.iloc[19:38, 6].replace(np.nan, df.iloc[19:38,6].mean(), inplace=True)
df.iloc[19:38, 7].replace(np.nan, df.iloc[19:38, 7].mean(), inplace=True)
df.iloc[19:38, 8].replace(np.nan, df.iloc[19:38, 8].mean(), inplace=True)
df.iloc[19:38, 9].replace(np.nan, df.iloc[19:38, 9].mean(), inplace=True)
df.iloc[19:38, 13].replace(np.nan, df.iloc[19:38, 13].mean(), inplace=True)

df.iloc[19:38, :].isnull().sum()
# Out:
# 99.97947368421053
# 2.0811237014
# 26.06144463368421
# 90.64313827894736
# 121.72116733157897
# 21.939104735263157
# 47.656501298421055
# 73.7179459305263
# 31.9625
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For United Arab Emirates
print(df.iloc[38:57, 1].mean()) #col1
print(df.iloc[38:57, 2].mean()) #col2
print(df.iloc[38:57, 3].mean()) #col3
print(df.iloc[38:57, 4].mean()) #col4
print(df.iloc[38:57, 6].mean()) #col6
print(df.iloc[38:57, 7].mean()) #col7
print(df.iloc[38:57, 8].mean()) #col8
print(df.iloc[38:57, 9].mean()) #col9
print(df.iloc[38:57, 13].mean()) #col13

df.iloc[38:57, 1].replace(np.nan, df.iloc[38:57, 1].mean(), inplace=True)
df.iloc[38:57, 2].replace(np.nan, df.iloc[38:57, 2].mean(), inplace=True)
df.iloc[38:57, 3].replace(np.nan, df.iloc[38:57, 3].mean(), inplace=True)
df.iloc[38:57, 4].replace(np.nan, df.iloc[38:57, 4].mean(), inplace=True)
df.iloc[38:57, 6].replace(np.nan, df.iloc[38:57,6].mean(), inplace=True)
df.iloc[38:57, 7].replace(np.nan, 48.6, inplace=True) #calculated manually
df.iloc[38:57, 8].replace(np.nan, df.iloc[38:57, 8].mean(), inplace=True)
df.iloc[38:57, 9].replace(np.nan, df.iloc[38:57, 9].mean(), inplace=True)
df.iloc[38:57, 13].replace(np.nan, df.iloc[38:57, 13].mean(), inplace=True)

df.iloc[38:57, :].isnull().sum()
# Out:
# 100.0
# -2.1942013304117642
# 80.69236520777778
# 57.356086941111116
# 80.83300199666667
# nan
# 61.52537797277777
# 142.21774318
# 29.25
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                0
# ...

# %%
#For Argentina
print(df.iloc[57:76, 1].mean()) #col1
print(df.iloc[57:76, 2].mean()) #col2
print(df.iloc[57:76, 3].mean()) #col3
print(df.iloc[57:76, 4].mean()) #col4
print(df.iloc[57:76, 6].mean()) #col6
print(df.iloc[57:76, 7].mean()) #col7
print(df.iloc[57:76, 8].mean()) #col8
print(df.iloc[57:76, 9].mean()) #col9
print(df.iloc[57:76, 13].mean()) #col13

df.iloc[57:76, 1].replace(np.nan, df.iloc[57:76, 1].mean(), inplace=True)
df.iloc[57:76, 2].replace(np.nan, df.iloc[57:76, 2].mean(), inplace=True)
df.iloc[57:76, 3].replace(np.nan, df.iloc[57:76, 3].mean(), inplace=True)
df.iloc[57:76, 4].replace(np.nan, df.iloc[57:76, 4].mean(), inplace=True)
df.iloc[57:76, 6].replace(np.nan, df.iloc[57:76,6].mean(), inplace=True)
df.iloc[57:76, 7].replace(np.nan, df.iloc[57:76, 7].mean(), inplace=True)
df.iloc[57:76, 8].replace(np.nan, df.iloc[57:76, 8].mean(), inplace=True)
df.iloc[57:76, 9].replace(np.nan, df.iloc[57:76, 9].mean(), inplace=True)
df.iloc[57:76, 13].replace(np.nan, df.iloc[57:76, 13].mean(), inplace=True)

df.iloc[57:76, :].isnull().sum()
# Out:
# 98.06023372894738
# 1.9158921998947376
# 18.05790292473684
# 79.6003899136842
# 96.71477861578948
# 16.834007959999997
# 14.965446042631578
# 33.02334896736841
# 45.59444444444444
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Armenia
print(df.iloc[76:95, 1].mean()) #col1
print(df.iloc[76:95, 2].mean()) #col2
print(df.iloc[76:95, 3].mean()) #col3
print(df.iloc[76:95, 4].mean()) #col4
print(df.iloc[76:95, 6].mean()) #col6
print(df.iloc[76:95, 7].mean()) #col7
print(df.iloc[76:95, 8].mean()) #col8
print(df.iloc[76:95, 9].mean()) #col9
print(df.iloc[76:95, 13].mean()) #col13

df.iloc[76:95, 1].replace(np.nan, df.iloc[76:95, 1].mean(), inplace=True)
df.iloc[76:95, 2].replace(np.nan, df.iloc[76:95, 2].mean(), inplace=True)
df.iloc[76:95, 3].replace(np.nan, df.iloc[76:95, 3].mean(), inplace=True)
df.iloc[76:95, 4].replace(np.nan, df.iloc[76:95, 4].mean(), inplace=True)
df.iloc[76:95, 6].replace(np.nan, df.iloc[76:95,6].mean(), inplace=True)
df.iloc[76:95, 7].replace(np.nan, df.iloc[76:95, 7].mean(), inplace=True)
df.iloc[76:95, 8].replace(np.nan, df.iloc[76:95, 8].mean(), inplace=True)
df.iloc[76:95, 9].replace(np.nan, df.iloc[76:95, 9].mean(), inplace=True)
df.iloc[76:95, 13].replace(np.nan, df.iloc[76:95, 13].mean(), inplace=True)

df.iloc[76:95, :].isnull().sum()
# Out:
# 99.45472563052631
# 6.5360339438421065
# 26.169693821052633
# 95.48272194052632
# 124.82832474210528
# 16.280763772684214
# 45.407951101052625
# 71.57764491947368
# 32.15555555555555
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Australia
print(df.iloc[95:114, 1].mean()) #col1
print(df.iloc[95:114, 2].mean()) #col2
print(df.iloc[95:114, 3].mean()) #col3
print(df.iloc[95:114, 4].mean()) #col4
print(df.iloc[95:114, 6].mean()) #col6
print(df.iloc[95:114, 7].mean()) #col7
print(df.iloc[95:114, 8].mean()) #col8
print(df.iloc[95:114, 9].mean()) #col9
print(df.iloc[95:114, 13].mean()) #col13

df.iloc[95:114, 1].replace(np.nan, df.iloc[95:114, 1].mean(), inplace=True)
df.iloc[95:114, 2].replace(np.nan, 4.77569 , inplace=True) #Calculated manually
df.iloc[95:114, 3].replace(np.nan, df.iloc[95:114, 3].mean(), inplace=True)
df.iloc[95:114, 4].replace(np.nan, df.iloc[95:114, 4].mean(), inplace=True)
df.iloc[95:114, 6].replace(np.nan, df.iloc[95:114,6].mean(), inplace=True)
df.iloc[95:114, 7].replace(np.nan, df.iloc[95:114, 7].mean(), inplace=True)
df.iloc[95:114, 8].replace(np.nan, df.iloc[95:114, 8].mean(), inplace=True)
df.iloc[95:114, 9].replace(np.nan, df.iloc[95:114, 9].mean(), inplace=True)
df.iloc[95:114, 13].replace(np.nan, df.iloc[95:114, 13].mean(), inplace=True)

df.iloc[95:114, :].isnull().sum()
# Out:
# 100.0
# nan
# 20.328889351052634
# 74.63498580105264
# 101.06840692789474
# 22.146533901578945
# 21.397348301578948
# 41.726237653157895
# 34.1
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                0
# ...

# %%
#For Austria
print(df.iloc[114:133, 1].mean()) #col1
print(df.iloc[114:133, 2].mean()) #col2
print(df.iloc[114:133, 3].mean()) #col3
print(df.iloc[114:133, 4].mean()) #col4
print(df.iloc[114:133, 6].mean()) #col6
print(df.iloc[114:133, 7].mean()) #col7
print(df.iloc[114:133, 8].mean()) #col8
print(df.iloc[114:133, 9].mean()) #col9
print(df.iloc[114:133, 13].mean()) #col13

df.iloc[114:133, 1].replace(np.nan, df.iloc[114:133, 1].mean(), inplace=True)
df.iloc[114:133, 2].replace(np.nan, df.iloc[114:133, 2].mean(), inplace=True)
df.iloc[114:133, 3].replace(np.nan, df.iloc[114:133, 3].mean(), inplace=True)
df.iloc[114:133, 4].replace(np.nan, df.iloc[114:133, 4].mean(), inplace=True)
df.iloc[114:133, 6].replace(np.nan, df.iloc[114:133,6].mean(), inplace=True)
df.iloc[114:133, 7].replace(np.nan, df.iloc[114:133, 7].mean(), inplace=True)
df.iloc[114:133, 8].replace(np.nan, df.iloc[114:133, 8].mean(), inplace=True)
df.iloc[114:133, 9].replace(np.nan, df.iloc[114:133, 9].mean(), inplace=True)
df.iloc[114:133, 13].replace(np.nan, df.iloc[114:133, 13].mean(), inplace=True)

df.iloc[114:133, :].isnull().sum()
# Out:
# 100.0
# 0.8765952023157894
# 50.33957360631579
# 72.68396718473686
# 96.83576443736843
# 26.40449842214286
# 47.15124170263158
# 97.49081531
# 30.211764705882356
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Azerbaijan
print(df.iloc[133:152, 1].mean()) #col1
print(df.iloc[133:152, 2].mean()) #col2
print(df.iloc[133:152, 3].mean()) #col3
print(df.iloc[133:152, 4].mean()) #col4
print(df.iloc[133:152, 6].mean()) #col6
print(df.iloc[133:152, 7].mean()) #col7
print(df.iloc[133:152, 8].mean()) #col8
print(df.iloc[133:152, 9].mean()) #col9
print(df.iloc[133:152, 13].mean()) #col13

df.iloc[133:152 ,1].replace(np.nan, df.iloc[133:152, 1].mean(), inplace=True)
df.iloc[133:152 ,2].replace(np.nan, df.iloc[133:152, 2].mean(), inplace=True)
df.iloc[133:152 ,3].replace(np.nan, df.iloc[133:152, 3].mean(), inplace=True)
df.iloc[133:152 ,4].replace(np.nan, df.iloc[133:152, 4].mean(), inplace=True)
df.iloc[133:152 ,6].replace(np.nan, df.iloc[133:152,6].mean(), inplace=True)
df.iloc[133:152 ,7].replace(np.nan, df.iloc[133:152, 7].mean(), inplace=True)
df.iloc[133:152 ,8].replace(np.nan, df.iloc[133:152, 8].mean(), inplace=True)
df.iloc[133:152 ,9].replace(np.nan, df.iloc[133:152, 9].mean(), inplace=True)
df.iloc[133:152 ,13].replace(np.nan, df.iloc[133:152, 13].mean(), inplace=True)

df.iloc[133:152, :].isnull().sum()
# Out:
# 99.65399223473685
# 14.801883070307694
# 51.18301384473684
# 59.91805291263157
# 87.78993688105264
# 34.04743501947369
# 37.42982223421052
# 88.61283607473683
# 28.360000000000003
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Burundi
print(df.iloc[152:171, 1].mean()) #col1
print(df.iloc[152:171, 2].mean()) #col2
print(df.iloc[152:171, 3].mean()) #col3
print(df.iloc[152:171, 4].mean()) #col4
print(df.iloc[152:171, 6].mean()) #col6
print(df.iloc[152:171, 7].mean()) #col7
print(df.iloc[152:171, 8].mean()) #col8
print(df.iloc[152:171, 9].mean()) #col9
print(df.iloc[152:171, 13].mean()) #col13

df.iloc[152:171 ,1].replace(np.nan, df.iloc[152:171, 1].mean(), inplace=True)
df.iloc[152:171 ,2].replace(np.nan, df.iloc[152:171, 2].mean(), inplace=True)
df.iloc[152:171 ,3].replace(np.nan, df.iloc[152:171, 3].mean(), inplace=True)
df.iloc[152:171 ,4].replace(np.nan, df.iloc[152:171, 4].mean(), inplace=True)
df.iloc[152:171 ,6].replace(np.nan, df.iloc[152:171,6].mean(), inplace=True)
df.iloc[152:171 ,7].replace(np.nan, df.iloc[152:171, 7].mean(), inplace=True)
df.iloc[152:171 ,8].replace(np.nan, df.iloc[152:171, 8].mean(), inplace=True)
df.iloc[152:171 ,9].replace(np.nan, df.iloc[152:171, 9].mean(), inplace=True)
df.iloc[152:171 ,13].replace(np.nan, df.iloc[152:171, 13].mean(), inplace=True)

df.iloc[152:171, :].isnull().sum()
# Out:
# 5.57571714368421
# 1.698681304684211
# 7.423834726315791
# 106.60205898526317
# 118.89811992105263
# 5.660056998947368
# 28.149543820526315
# 35.57337854736842
# 36.0
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Belgium
print(df.iloc[171:190, 1].mean()) #col1
print(df.iloc[171:190, 2].mean()) #col2
print(df.iloc[171:190, 3].mean()) #col3
print(df.iloc[171:190, 4].mean()) #col4
print(df.iloc[171:190, 6].mean()) #col6
print(df.iloc[171:190, 7].mean()) #col7
print(df.iloc[171:190, 8].mean()) #col8
print(df.iloc[171:190, 9].mean()) #col9
print(df.iloc[171:190, 13].mean()) #col13

df.iloc[171:190 ,1].replace(np.nan, df.iloc[171:190, 1].mean(), inplace=True)
df.iloc[171:190 ,2].replace(np.nan, df.iloc[171:190, 2].mean(), inplace=True)
df.iloc[171:190 ,3].replace(np.nan, df.iloc[171:190, 3].mean(), inplace=True)
df.iloc[171:190 ,4].replace(np.nan, df.iloc[171:190, 4].mean(), inplace=True)
df.iloc[171:190 ,6].replace(np.nan, df.iloc[171:190,6].mean(), inplace=True)
df.iloc[171:190 ,7].replace(np.nan, df.iloc[171:190, 7].mean(), inplace=True)
df.iloc[171:190 ,8].replace(np.nan, df.iloc[171:190, 8].mean(), inplace=True)
df.iloc[171:190 ,9].replace(np.nan, df.iloc[171:190, 9].mean(), inplace=True)
df.iloc[171:190 ,13].replace(np.nan, df.iloc[171:190, 13].mean(), inplace=True)

df.iloc[171:190, :].isnull().sum()
# Out:
# 100.0
# 0.6457573695789475
# 76.50146567526315
# 74.20910367578946
# 97.67577200578948
# 25.77706523647059
# 74.17723768263158
# 150.67870335263157
# 28.52941176470588
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Benin
print(df.iloc[190:209, 1].mean()) #col1
print(df.iloc[190:209, 2].mean()) #col2
print(df.iloc[190:209, 3].mean()) #col3
print(df.iloc[190:209, 4].mean()) #col4
print(df.iloc[190:209, 6].mean()) #col6
print(df.iloc[190:209, 7].mean()) #col7
print(df.iloc[190:209, 8].mean()) #col8
print(df.iloc[190:209, 9].mean()) #col9
print(df.iloc[190:209, 13].mean()) #col13

df.iloc[190:209 ,1].replace(np.nan, df.iloc[190:209, 1].mean(), inplace=True)
df.iloc[190:209 ,2].replace(np.nan, df.iloc[190:209, 2].mean(), inplace=True)
df.iloc[190:209 ,3].replace(np.nan, df.iloc[190:209, 3].mean(), inplace=True)
df.iloc[190:209 ,4].replace(np.nan, df.iloc[190:209, 4].mean(), inplace=True)
df.iloc[190:209 ,6].replace(np.nan, df.iloc[190:209,6].mean(), inplace=True)
df.iloc[190:209 ,7].replace(np.nan, df.iloc[190:209, 7].mean(), inplace=True)
df.iloc[190:209 ,8].replace(np.nan, df.iloc[190:209, 8].mean(), inplace=True)
df.iloc[190:209 ,9].replace(np.nan, df.iloc[190:209, 9].mean(), inplace=True)
df.iloc[190:209 ,13].replace(np.nan, df.iloc[190:209, 13].mean(), inplace=True)

df.iloc[190:209, :].isnull().sum()
# Out:
# 30.357739073684204
# 2.1171229248947365
# 22.718958347894738
# 87.64261813842106
# 104.7869773
# 14.068868085789473
# 27.505936456315787
# 50.224894803157895
# 43.26666666666667
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Burkina Faso
print(df.iloc[209:228, 1].mean()) #col1
print(df.iloc[209:228, 2].mean()) #col2
print(df.iloc[209:228, 3].mean()) #col3
print(df.iloc[209:228, 4].mean()) #col4
print(df.iloc[209:228, 6].mean()) #col6
print(df.iloc[209:228, 7].mean()) #col7
print(df.iloc[209:228, 8].mean()) #col8
print(df.iloc[209:228, 9].mean()) #col9
print(df.iloc[209:228, 13].mean()) #col13

df.iloc[209:228 ,1].replace(np.nan, df.iloc[209:228, 1].mean(), inplace=True)
df.iloc[209:228 ,2].replace(np.nan, df.iloc[209:228, 2].mean(), inplace=True)
df.iloc[209:228 ,3].replace(np.nan, df.iloc[209:228, 3].mean(), inplace=True)
df.iloc[209:228 ,4].replace(np.nan, df.iloc[209:228, 4].mean(), inplace=True)
df.iloc[209:228 ,6].replace(np.nan, df.iloc[209:228,6].mean(), inplace=True)
df.iloc[209:228 ,7].replace(np.nan, df.iloc[209:228, 7].mean(), inplace=True)
df.iloc[209:228 ,8].replace(np.nan, df.iloc[209:228, 8].mean(), inplace=True)
df.iloc[209:228 ,9].replace(np.nan, df.iloc[209:228, 9].mean(), inplace=True)
df.iloc[209:228 ,13].replace(np.nan, df.iloc[209:228, 13].mean(), inplace=True)

df.iloc[209:228, :].isnull().sum()
# Out:
# 13.344289904736842
# 2.8305913754736842
# 17.67713053105263
# 91.38092472526316
# 110.43023854736843
# 12.860917279928572
# 28.10736907105263
# 45.78449960210527
# 39.46666666666666
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Bangladesh
print(df.iloc[228:247, 1].mean()) #col1
print(df.iloc[228:247, 2].mean()) #col2
print(df.iloc[228:247, 3].mean()) #col3
print(df.iloc[228:247, 4].mean()) #col4
print(df.iloc[228:247, 6].mean()) #col6
print(df.iloc[228:247, 7].mean()) #col7
print(df.iloc[228:247, 8].mean()) #col8
print(df.iloc[228:247, 9].mean()) #col9
print(df.iloc[228:247, 13].mean()) #col13

df.iloc[228:247 ,1].replace(np.nan, df.iloc[228:247, 1].mean(), inplace=True)
df.iloc[228:247 ,2].replace(np.nan, df.iloc[228:247, 2].mean(), inplace=True)
df.iloc[228:247 ,3].replace(np.nan, df.iloc[228:247, 3].mean(), inplace=True)
df.iloc[228:247 ,4].replace(np.nan, df.iloc[228:247, 4].mean(), inplace=True)
df.iloc[228:247 ,6].replace(np.nan, df.iloc[228:247,6].mean(), inplace=True)
df.iloc[228:247 ,7].replace(np.nan, df.iloc[228:247, 7].mean(), inplace=True)
df.iloc[228:247 ,8].replace(np.nan, df.iloc[228:247, 8].mean(), inplace=True)
df.iloc[228:247 ,9].replace(np.nan, df.iloc[228:247, 9].mean(), inplace=True)
df.iloc[228:247 ,13].replace(np.nan, df.iloc[228:247, 13].mean(), inplace=True)

df.iloc[228:247, :].isnull().sum()
# Out:
# 56.485728233684206
# 4.597133050263158
# 15.869357047894736
# 78.54176490789474
# 105.47538645789476
# 35.07370320578947
# 21.90972018105263
# 37.77907722684212
# 32.775
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Bulgaria
print(df.iloc[247:266, 1].mean()) #col1
print(df.iloc[247:266, 2].mean()) #col2
print(df.iloc[247:266, 3].mean()) #col3
print(df.iloc[247:266, 4].mean()) #col4
print(df.iloc[247:266, 6].mean()) #col6
print(df.iloc[247:266, 7].mean()) #col7
print(df.iloc[247:266, 8].mean()) #col8
print(df.iloc[247:266, 9].mean()) #col9
print(df.iloc[247:266, 13].mean()) #col13

df.iloc[247:266 ,1].replace(np.nan, df.iloc[247:266, 1].mean(), inplace=True)
df.iloc[247:266 ,2].replace(np.nan, df.iloc[247:266, 2].mean(), inplace=True)
df.iloc[247:266 ,3].replace(np.nan, df.iloc[247:266, 3].mean(), inplace=True)
df.iloc[247:266 ,4].replace(np.nan, df.iloc[247:266, 4].mean(), inplace=True)
df.iloc[247:266 ,6].replace(np.nan, df.iloc[247:266,6].mean(), inplace=True)
df.iloc[247:266 ,7].replace(np.nan, df.iloc[247:266, 7].mean(), inplace=True)
df.iloc[247:266 ,8].replace(np.nan, df.iloc[247:266, 8].mean(), inplace=True)
df.iloc[247:266 ,9].replace(np.nan, df.iloc[247:266, 9].mean(), inplace=True)
df.iloc[247:266 ,13].replace(np.nan, df.iloc[247:266, 13].mean(), inplace=True)

df.iloc[247:266, :].isnull().sum()
# Out:
# 100.0
# 5.087922402684211
# 51.454746924736845
# 82.18446667263159
# 106.14856913894737
# 19.29632156284211
# 57.60331607
# 109.05806300157894
# 36.93076923076923
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# ...

# %%
#For Bahrain
print(df.iloc[266:285, 1].mean()) #col1
print(df.iloc[266:285, 2].mean()) #col2
print(df.iloc[266:285, 3].mean()) #col3
print(df.iloc[266:285, 4].mean()) #col4
print(df.iloc[266:285, 6].mean()) #col6
print(df.iloc[266:285, 7].mean()) #col7
print(df.iloc[266:285, 8].mean()) #col8
print(df.iloc[266:285, 9].mean()) #col9
print(df.iloc[266:285, 13].mean()) #col13

df.iloc[266:285,1].replace(np.nan, df.iloc[266:285, 1].mean(), inplace=True)
df.iloc[266:285,2].replace(np.nan, df.iloc[266:285, 2].mean(), inplace=True)
df.iloc[266:285,3].replace(np.nan, df.iloc[266:285, 3].mean(), inplace=True)
df.iloc[266:285,4].replace(np.nan, df.iloc[266:285, 4].mean(), inplace=True)
df.iloc[266:285,6].replace(np.nan, df.iloc[266:285, 6].mean(), inplace=True)
df.iloc[266:285,7].replace(np.nan, df.iloc[266:285, 7].mean(), inplace=True)
df.iloc[266:285,8].replace(np.nan, df.iloc[266:285, 8].mean(), inplace=True)
df.iloc[266:285,9].replace(np.nan, df.iloc[266:285, 9].mean(), inplace=True)
df.iloc[266:285,13].replace(np.nan, 26, inplace=True) #Calculated manually

df.iloc[266:285, :].isnull().sum()
# Out:
# 100.0
# 0.8387814286666669
# 82.09661413
# 56.37388904105263
# 83.00928581736841
# 30.49501517210526
# 65.10587616368421
# 147.20249029473686
# nan
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                0
# ...

# %%
#For Bahamas, The
print(df.iloc[285:304, 1].mean()) #col1
print(df.iloc[285:304, 2].mean()) #col2
print(df.iloc[285:304, 3].mean()) #col3
print(df.iloc[285:304, 4].mean()) #col4
print(df.iloc[285:304, 6].mean()) #col6
print(df.iloc[285:304, 7].mean()) #col7
print(df.iloc[285:304, 8].mean()) #col8
print(df.iloc[285:304, 9].mean()) #col9
print(df.iloc[285:304, 13].mean()) #col13

df.iloc[285:304,1].replace(np.nan, df.iloc[285:304, 1].mean(), inplace=True)
df.iloc[285:304,2].replace(np.nan, df.iloc[285:304, 2].mean(), inplace=True)
df.iloc[285:304,3].replace(np.nan, df.iloc[285:304, 3].mean(), inplace=True)
df.iloc[285:304,4].replace(np.nan, df.iloc[285:304, 4].mean(), inplace=True)
df.iloc[285:304,6].replace(np.nan, df.iloc[285:304, 6].mean(), inplace=True)
df.iloc[285:304,7].replace(np.nan, df.iloc[285:304, 7].mean(), inplace=True)
df.iloc[285:304,8].replace(np.nan, df.iloc[285:304, 8].mean(), inplace=True)
df.iloc[285:304,9].replace(np.nan, df.iloc[285:304, 9].mean(), inplace=True)
df.iloc[285:304,13].replace(np.nan, 57, inplace=True) #Calculated manually

df.iloc[285:304, :].isnull().sum()
# Out:
# 100.0
# -0.780549961842105
# 37.4935410468421
# 72.51812502368419
# 100.45425380052632
# 25.791624847368425
# 42.380115886842106
# 79.87365693473684
# nan
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                0
# ...

# %%
#Bosnia and Herzegovina
print(df.iloc[304:323, 1].mean()) #col1
print(df.iloc[304:323, 2].mean()) #col2
print(df.iloc[304:323, 3].mean()) #col3
print(df.iloc[304:323, 4].mean()) #col4
print(df.iloc[304:323, 6].mean()) #col6
print(df.iloc[304:323, 7].mean()) #col7
print(df.iloc[304:323, 8].mean()) #col8
print(df.iloc[304:323, 9].mean()) #col9
print(df.iloc[304:323, 13].mean()) #col13

df.iloc[304:323,1].replace(np.nan, df.iloc[304:323, 1].mean(), inplace=True)
df.iloc[304:323,2].replace(np.nan, df.iloc[304:323, 2].mean(), inplace=True)
df.iloc[304:323,3].replace(np.nan, df.iloc[304:323, 3].mean(), inplace=True)
df.iloc[304:323,4].replace(np.nan, df.iloc[304:323, 4].mean(), inplace=True)
df.iloc[304:323,6].replace(np.nan, df.iloc[304:323, 6].mean(), inplace=True)
df.iloc[304:323,7].replace(np.nan, df.iloc[304:323, 7].mean(), inplace=True)
df.iloc[304:323,8].replace(np.nan, df.iloc[304:323, 8].mean(), inplace=True)
df.iloc[304:323,9].replace(np.nan, df.iloc[304:323, 9].mean(), inplace=True)
df.iloc[304:323,13].replace(np.nan, df.iloc[304:323,13].mean(), inplace=True)

df.iloc[304:323, :].isnull().sum()
# Out:
# 99.78384513368421
# 2.717759474583333
# 31.69597279421053
# 106.805949186
# 128.49006479333335
# 9.5729785524
# 61.382590671052625
# 93.07856346105264
# 32.525
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                0
# ...

# %%
df.isnull().sum()
# Out:
# Country Name                                                                             0
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                 0
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG         0
# Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                0
# Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                0
# GDP (current US$) - NY.GDP.MKTP.CD                                                       0
# Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                   0
# Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                0
# Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                0
# Trade (% of GDP) - NE.TRD.GNFS.ZS                                                        0
# ...

# %%
sns.heatmap(df.isnull(), yticklabels= False, cbar=False, cmap="viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. All the null values are replaced by 0
# 2. Filled the 0 using the Arithmatic Mean of every columns of each country indivisually.
# 3. Now, There are no outliers or missing values and we are ready for further analysis ***
